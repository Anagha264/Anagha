# %% [markdown]
# <a href="https://colab.research.google.com/github/Anagha264/Anagha/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print(os.listdir('/content/drive'))
# Out:
# ['.shortcut-targets-by-id', 'MyDrive', '.Trash-0', '.Encrypted']

# %%
print(os.listdir('/content/drive/MyDrive'))
# Out:
# ['Colab Notebooks', 'Google AI Studio', 'Research paper ', 'Ostroporosis']

# %%
print(os.listdir('/content/drive/MyDrive/Ostroporosis'))
# Out:
# ['dataset']

# %%
print(os.listdir('/content/drive/MyDrive/Ostroporosis/dataset'))
# Out:
# ['test', 'train']

# %%
train_dir = "/content/drive/MyDrive/Ostroporosis/dataset/train"
test_dir = "/content/drive/MyDrive/Ostroporosis/dataset/test"

# %%
# ================== MOUNT DRIVE ==================
from google.colab import drive
drive.mount('/content/drive')

# ================== IMPORTS ==================
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50, VGG19, DenseNet121
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter

# ================== PATH ==================
train_dir = "/content/drive/MyDrive/Ostroporosis/dataset/train"
test_dir  = "/content/drive/MyDrive/Ostroporosis/dataset/test"

# ================== PARAMETERS ==================
img_size = 160      # 🔥 faster than 224
batch_size = 32     # 🔥 faster
epochs = 10         # 🔥 balanced

# ================== DATA ==================
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=10,
    zoom_range=0.1,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# ================== CLASS BALANCE CHECK ==================
print("\nClass Distribution:")
print(Counter(train_generator.classes))

# ================== CLASS WEIGHTS ==================
labels = train_generator.classes

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)

class_weights = dict(enumerate(class_weights))

print("\nClass Weights:", class_weights)

# ================== CALLBACK ==================
early_stop = EarlyStopping(monitor='val_accuracy', patience=2, restore_best_weights=True)

# ================== MODELS ==================

def build_resnet():
    base = ResNet50(weights='imagenet', include_top=False, input_shape=(160,160,3))
    base.trainable = False

    x = GlobalAveragePooling2D()(base.output)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    out = Dense(3, activation='softmax')(x)

    return Model(base.input, out)


def build_vgg():
    base = VGG19(weights='imagenet', include_top=False, input_shape=(160,160,3))
    base.trainable = False

    x = GlobalAveragePooling2D()(base.output)
    x = Dense(128, activation='relu')(x)
    out = Dense(3, activation='softmax')(x)

    return Model(base.input, out)


def build_densenet():
    base = DenseNet121(weights='imagenet', include_top=False, input_shape=(160,160,3))
    base.trainable = False

    x = GlobalAveragePooling2D()(base.output)
    x = Dense(128, activation='relu')(x)
    out = Dense(3, activation='softmax')(x)

    return Model(base.input, out)


def build_alexnet():
    model = Sequential([
        Conv2D(64,(3,3),activation='relu',input_shape=(160,160,3)),
        MaxPooling2D((2,2)),

        Conv2D(128,(3,3),activation='relu'),
        MaxPooling2D((2,2)),

        Flatten(),
        Dense(256,activation='relu'),
        Dropout(0.5),
        Dense(3,activation='softmax')
    ])
    return model


# ================== TRAIN FUNCTION ==================
def train_model(model, name):

    print(f"\n🚀 Training {name}...\n")

    model.compile(
        optimizer=Adam(1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=epochs,
        callbacks=[early_stop],
        class_weight=class_weights   # 🔥 IMPORTANT
    )

    # ===== GRAPH =====
    plt.figure()
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='val')
    plt.title(name + " Accuracy")
    plt.legend()
    plt.show()

    # ===== CONFUSION MATRIX =====
    y_pred = model.predict(test_generator)
    y_pred_classes = np.argmax(y_pred, axis=1)

    cm = confusion_matrix(test_generator.classes, y_pred_classes)

    plt.figure()
    sns.heatmap(cm, annot=True, fmt='d')
    plt.title(name + " Confusion Matrix")
    plt.show()

    # ===== REPORT =====
    print("\n📄 Classification Report:\n")
    print(classification_report(
        test_generator.classes,
        y_pred_classes,
        target_names=list(test_generator.class_indices.keys())
    ))

    # ===== FINAL ACCURACY =====
    score = model.evaluate(test_generator)
    print(f"🔥 {name} Accuracy:", score[1])

    return score[1]


# ================== RUN ==================
results = {}

results["ResNet"]   = train_model(build_resnet(), "ResNet")
results["VGG19"]    = train_model(build_vgg(), "VGG19")
results["DenseNet"] = train_model(build_densenet(), "DenseNet")
results["AlexNet"]  = train_model(build_alexnet(), "AlexNet")

# ================== FINAL RESULT ==================
print("\n📊 FINAL COMPARISON:")
for model, acc in results.items():
    print(f"{model}: {acc}")
# Out:
# Mounted at /content/drive
# Found 3348 images belonging to 3 classes.
# Found 835 images belonging to 3 classes.
# Found 648 images belonging to 3 classes.
#
# Class Distribution:
# Counter({np.int32(2): 1461, np.int32(1): 1107, np.int32(0): 780})
#
# Class Weights: {0: np.float64(1.4307692307692308), 1: np.float64(1.008130081300813), 2: np.float64(0.7638603696098563)}
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# 🚀 Training ResNet...
#
# Epoch 1/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1115s 11s/step - accuracy: 0.6027 - loss: 1.0385 - val_accuracy: 0.6000 - val_loss: 0.8145
# Epoch 2/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 102s 971ms/step - accuracy: 0.7013 - loss: 0.7697 - val_accuracy: 0.5796 - val_loss: 0.8424
# Epoch 3/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.7228 - loss: 0.6716 - val_accuracy: 0.6108 - val_loss: 0.9001
# Epoch 4/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 99s 944ms/step - accuracy: 0.7378 - loss: 0.6316 - val_accuracy: 0.6275 - val_loss: 0.8456
# Epoch 5/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 99s 944ms/step - accuracy: 0.7521 - loss: 0.5884 - val_accuracy: 0.6299 - val_loss: 0.8344
# Epoch 6/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 99s 946ms/step - accuracy: 0.7545 - loss: 0.5676 - val_accuracy: 0.6383 - val_loss: 0.7981
# Epoch 7/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.7709 - loss: 0.5317 - val_accuracy: 0.6347 - val_loss: 0.8272
# Epoch 8/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 99s 939ms/step - accuracy: 0.7864 - loss: 0.4930 - val_accuracy: 0.6551 - val_loss: 0.7743
# Epoch 9/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 100s 957ms/step - accuracy: 0.7751 - loss: 0.5224 - val_accuracy: 0.6407 - val_loss: 0.8276
# Epoch 10/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 99s 951ms/step - accuracy: 0.7864 - loss: 0.4853 - val_accuracy: 0.6443 - val_loss: 0.7513
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 228s 11s/step
# 📄 Classification Report:
#
#               precision    recall  f1-score   support
#
#       normal       0.79      0.51      0.62       227
#   osteopenia       0.69      0.86      0.76       186
# osteoporosis       0.61      0.69      0.65       235
#
#     accuracy                           0.68       648
#    macro avg       0.69      0.69      0.68       648
# weighted avg       0.69      0.68      0.67       648
#
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 374ms/step - accuracy: 0.6759 - loss: 1.6656
# 🔥 ResNet Accuracy: 0.6759259104728699
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# 🚀 Training VGG19...
#
# Epoch 1/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.4498 - loss: 1.7267 - val_accuracy: 0.5485 - val_loss: 1.2583
# Epoch 2/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.6231 - loss: 0.8952 - val_accuracy: 0.5677 - val_loss: 1.1352
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 359ms/step
# 📄 Classification Report:
#
#               precision    recall  f1-score   support
#
#       normal       0.60      0.41      0.48       227
#   osteopenia       0.54      0.76      0.63       186
# osteoporosis       0.49      0.49      0.49       235
#
#     accuracy                           0.54       648
#    macro avg       0.54      0.55      0.54       648
# weighted avg       0.54      0.54      0.53       648
#
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 277ms/step - accuracy: 0.5370 - loss: 1.6473
# 🔥 VGG19 Accuracy: 0.5370370149612427
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# 🚀 Training DenseNet...
#
# Epoch 1/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.4247 - loss: 3.9247 - val_accuracy: 0.4946 - val_loss: 1.3621
# Epoch 2/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.5777 - loss: 1.0128 - val_accuracy: 0.5509 - val_loss: 1.1162
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step
# 📄 Classification Report:
#
#               precision    recall  f1-score   support
#
#       normal       0.65      0.38      0.48       227
#   osteopenia       0.39      0.81      0.52       186
# osteoporosis       0.51      0.28      0.36       235
#
#     accuracy                           0.47       648
#    macro avg       0.52      0.49      0.45       648
# weighted avg       0.52      0.47      0.45       648
#
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 687ms/step - accuracy: 0.4660 - loss: 2.0746
# 🔥 DenseNet Accuracy: 0.4660493731498718
#
# 🚀 Training AlexNet...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.4773 - loss: 24.5095 - val_accuracy: 0.5485 - val_loss: 0.8456
# Epoch 2/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 102s 977ms/step - accuracy: 0.4875 - loss: 0.8930 - val_accuracy: 0.5713 - val_loss: 0.8435
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step
# 📄 Classification Report:
#
#               precision    recall  f1-score   support
#
#       normal       0.67      0.22      0.34       227
#   osteopenia       0.58      0.92      0.71       186
# osteoporosis       0.48      0.57      0.52       235
#
#     accuracy                           0.55       648
#    macro avg       0.58      0.57      0.52       648
# weighted avg       0.58      0.55      0.51       648
#
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 279ms/step - accuracy: 0.5494 - loss: 1.1213
# 🔥 AlexNet Accuracy: 0.5493826866149902
#
# 📊 FINAL COMPARISON:
# ResNet: 0.6759259104728699
# VGG19: 0.5370370149612427
# DenseNet: 0.4660493731498718
# AlexNet: 0.5493826866149902

# %%
# ================== MOUNT DRIVE ==================
from google.colab import drive
drive.mount('/content/drive')

# ================== IMPORTS ==================
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter

# ================== PATH ==================
train_dir = "/content/drive/MyDrive/Ostroporosis/dataset/train"
test_dir  = "/content/drive/MyDrive/Ostroporosis/dataset/test"

# ================== PARAMETERS ==================
img_size = 160
batch_size = 32
epochs = 15

# ================== DATA ==================
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=15,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# ================== CLASS BALANCE ==================
print("\nClass Distribution:")
print(Counter(train_generator.classes))

labels = train_generator.classes

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)
class_weights = dict(enumerate(class_weights))

print("\nClass Weights:", class_weights)

# ================== CALLBACKS ==================
early_stop = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)

lr_reduce = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-7,
    verbose=1
)

# ================== RESNET MODEL ==================
def build_resnet():
    base = ResNet50(weights='imagenet', include_top=False, input_shape=(160,160,3))

    # 🔥 Fine-tuning last layers
    for layer in base.layers[:-30]:
        layer.trainable = False
    for layer in base.layers[-30:]:
        layer.trainable = True

    x = GlobalAveragePooling2D()(base.output)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.6)(x)
    output = Dense(3, activation='softmax')(x)

    return Model(base.input, output)

# ================== BUILD MODEL ==================
model = build_resnet()

# ================== COMPILE ==================
model.compile(
    optimizer=Adam(1e-5),   # 🔥 low LR for fine-tuning
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ================== TRAIN ==================
print("\n🚀 Training ResNet...\n")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs,
    callbacks=[early_stop, lr_reduce],
    class_weight=class_weights
)

# ================== PLOTS ==================
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.legend()
plt.title("Accuracy")

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.title("Loss")

plt.show()

# ================== EVALUATION ==================
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(test_generator.classes, y_pred_classes)

plt.figure()
sns.heatmap(cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.show()

print("\n📄 Classification Report:\n")
print(classification_report(
    test_generator.classes,
    y_pred_classes,
    target_names=list(test_generator.class_indices.keys())
))

# ================== FINAL ACCURACY ==================
score = model.evaluate(test_generator)
print(f"\n🔥 FINAL RESNET ACCURACY: {score[1]}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 3348 images belonging to 3 classes.
# Found 835 images belonging to 3 classes.
# Found 648 images belonging to 3 classes.
#
# Class Distribution:
# Counter({np.int32(2): 1461, np.int32(1): 1107, np.int32(0): 780})
#
# Class Weights: {0: np.float64(1.4307692307692308), 1: np.float64(1.008130081300813), 2: np.float64(0.7638603696098563)}
#
# 🚀 Training ResNet...
#
# Epoch 1/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.4558 - loss: 1.3754 - val_accuracy: 0.4180 - val_loss: 1.2646 - learning_rate: 1.0000e-05
# Epoch 2/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.6216 - loss: 0.9885 - val_accuracy: 0.5401 - val_loss: 1.0902 - learning_rate: 1.0000e-05
# Epoch 3/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.6493 - loss: 0.9081 - val_accuracy: 0.5844 - val_loss: 1.0569 - learning_rate: 1.0000e-05
# Epoch 4/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.6747 - loss: 0.8327 - val_accuracy: 0.5796 - val_loss: 1.0797 - learning_rate: 1.0000e-05
# Epoch 5/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.6909 - loss: 0.7871 - val_accuracy: 0.5904 - val_loss: 1.0340 - learning_rate: 1.0000e-05
# Epoch 6/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.7252 - loss: 0.7035 - val_accuracy: 0.5916 - val_loss: 1.0320 - learning_rate: 1.0000e-05
# Epoch 7/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7282 - loss: 0.6900 - val_accuracy: 0.6120 - val_loss: 0.9818 - learning_rate: 1.0000e-05
# Epoch 8/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 104s 990ms/step - accuracy: 0.7473 - loss: 0.6374 - val_accuracy: 0.6072 - val_loss: 1.0092 - learning_rate: 1.0000e-05
# Epoch 9/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 105s 997ms/step - accuracy: 0.7434 - loss: 0.6210 - val_accuracy: 0.6144 - val_loss: 0.9423 - learning_rate: 1.0000e-05
# Epoch 10/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 105s 996ms/step - accuracy: 0.7518 - loss: 0.6138 - val_accuracy: 0.6216 - val_loss: 0.9106 - learning_rate: 1.0000e-05
# Epoch 11/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 104s 996ms/step - accuracy: 0.7566 - loss: 0.6016 - val_accuracy: 0.6263 - val_loss: 0.9137 - learning_rate: 1.0000e-05
# Epoch 12/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 104s 992ms/step - accuracy: 0.7557 - loss: 0.6088 - val_accuracy: 0.6299 - val_loss: 0.8832 - learning_rate: 1.0000e-05
# Epoch 13/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 104s 989ms/step - accuracy: 0.7533 - loss: 0.5754 - val_accuracy: 0.6144 - val_loss: 0.8907 - learning_rate: 1.0000e-05
# Epoch 14/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 122s 1s/step - accuracy: 0.7706 - loss: 0.5393 - val_accuracy: 0.6407 - val_loss: 0.8617 - learning_rate: 1.0000e-05
# Epoch 15/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 103s 979ms/step - accuracy: 0.7790 - loss: 0.5240 - val_accuracy: 0.6491 - val_loss: 0.8423 - learning_rate: 1.0000e-05
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 427ms/step
# 📄 Classification Report:
#
#               precision    recall  f1-score   support
#
#       normal       0.84      0.48      0.61       227
#   osteopenia       0.65      0.89      0.75       186
# osteoporosis       0.62      0.70      0.66       235
#
#     accuracy                           0.68       648
#    macro avg       0.70      0.69      0.67       648
# weighted avg       0.71      0.68      0.67       648
#
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - accuracy: 0.6759 - loss: 1.7712
#
# 🔥 FINAL RESNET ACCURACY: 0.6759259104728699

# %%
# ================== MOUNT DRIVE ==================
from google.colab import drive
drive.mount('/content/drive')

# ================== IMPORTS ==================
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50, VGG19, DenseNet121
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight

# ================== PATH ==================
train_dir = "/content/drive/MyDrive/Ostroporosis/dataset/train"
test_dir  = "/content/drive/MyDrive/Ostroporosis/dataset/test"

# ================== PARAMETERS ==================
img_size = 160   # 🔥 faster + good accuracy
batch_size = 32
epochs_resnet = 15
epochs_other = 6

# ================== DATA ==================
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=15,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# ================== CLASS WEIGHTS ==================
labels = train_generator.classes
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)
class_weights = dict(enumerate(class_weights))

# ================== CALLBACKS ==================
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

lr_reduce = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-6,
    verbose=1
)

# ================== MODELS ==================

# 🔥 RESNET (BEST MODEL)
def build_resnet():
    base = ResNet50(weights='imagenet', include_top=False, input_shape=(160,160,3))
    for layer in base.layers[:-80]:
        layer.trainable = False
    for layer in base.layers[-80:]:
        layer.trainable = True

    x = GlobalAveragePooling2D()(base.output)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.4)(x)
    out = Dense(3, activation='softmax')(x)

    return Model(base.input, out)

# VGG19
def build_vgg():
    base = VGG19(weights='imagenet', include_top=False, input_shape=(160,160,3))
    base.trainable = False

    x = GlobalAveragePooling2D()(base.output)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.4)(x)
    out = Dense(3, activation='softmax')(x)

    return Model(base.input, out)

# DenseNet
def build_densenet():
    base = DenseNet121(weights='imagenet', include_top=False, input_shape=(160,160,3))
    base.trainable = False

    x = GlobalAveragePooling2D()(base.output)
    x = Dense(256, activation='relu')(x)
    out = Dense(3, activation='softmax')(x)

    return Model(base.input, out)

# AlexNet
def build_alexnet():
    model = Sequential([
        Conv2D(64,(11,11),strides=4,activation='relu',input_shape=(160,160,3)),
        MaxPooling2D((3,3),strides=2),

        Conv2D(192,(5,5),padding='same',activation='relu'),
        MaxPooling2D((3,3),strides=2),

        Conv2D(384,(3,3),padding='same',activation='relu'),
        Conv2D(256,(3,3),padding='same',activation='relu'),

        MaxPooling2D((3,3),strides=2),

        Flatten(),
        Dense(256,activation='relu'),
        Dropout(0.5),
        Dense(3,activation='softmax')
    ])
    return model

# ================== TRAIN FUNCTION ==================
def train_model(model, name, epochs):

    print(f"\n🚀 Training {name}...\n")

    model.compile(
        optimizer=Adam(1e-5),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=epochs,
        callbacks=[early_stop, lr_reduce],
        class_weight=class_weights
    )

    # ===== PLOTS =====
    plt.figure(figsize=(12,5))

    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='val')
    plt.title(f"{name} Accuracy")
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='val')
    plt.title(f"{name} Loss")
    plt.legend()

    plt.show()

    # ===== EVALUATION =====
    y_pred = model.predict(test_generator)
    y_pred_classes = np.argmax(y_pred, axis=1)

    cm = confusion_matrix(test_generator.classes, y_pred_classes)

    plt.figure()
    sns.heatmap(cm, annot=True, fmt='d')
    plt.title(f"{name} Confusion Matrix")
    plt.show()

    print(classification_report(
        test_generator.classes,
        y_pred_classes,
        target_names=list(test_generator.class_indices.keys())
    ))

    score = model.evaluate(test_generator)
    print(f"🔥 {name} Accuracy:", score[1])

    return score[1]

# ================== RUN ALL MODELS ==================
results = {}

results["ResNet"]   = train_model(build_resnet(), "ResNet", epochs_resnet)
results["VGG19"]    = train_model(build_vgg(), "VGG19", epochs_other)
results["DenseNet"] = train_model(build_densenet(), "DenseNet", epochs_other)
results["AlexNet"]  = train_model(build_alexnet(), "AlexNet", epochs_other)

# ================== FINAL COMPARISON ==================
print("\n📊 FINAL MODEL COMPARISON:")
for model, acc in results.items():
    print(f"{model}: {acc}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 3348 images belonging to 3 classes.
# Found 835 images belonging to 3 classes.
# Found 648 images belonging to 3 classes.
#
# 🚀 Training ResNet...
#
# Epoch 1/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.5618 - loss: 1.1677 - val_accuracy: 0.5677 - val_loss: 1.0079 - learning_rate: 1.0000e-05
# Epoch 2/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 101s 965ms/step - accuracy: 0.6631 - loss: 0.9511 - val_accuracy: 0.5988 - val_loss: 0.9675 - learning_rate: 1.0000e-05
# Epoch 3/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 104s 993ms/step - accuracy: 0.7007 - loss: 0.8594 - val_accuracy: 0.6000 - val_loss: 1.0662 - learning_rate: 1.0000e-05
# Epoch 4/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 756ms/step - accuracy: 0.7016 - loss: 0.8843
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 103s 984ms/step - accuracy: 0.7124 - loss: 0.8650 - val_accuracy: 0.6060 - val_loss: 1.0205 - learning_rate: 1.0000e-05
# Epoch 5/15
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 103s 978ms/step - accuracy: 0.7136 - loss: 0.8391 - val_accuracy: 0.6168 - val_loss: 1.0068 - learning_rate: 5.0000e-06
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 389ms/step
#               precision    recall  f1-score   support
#
#       normal       0.68      0.43      0.52       227
#   osteopenia       0.63      0.88      0.73       186
# osteoporosis       0.58      0.60      0.59       235
#
#     accuracy                           0.62       648
#    macro avg       0.63      0.63      0.61       648
# weighted avg       0.63      0.62      0.61       648
#
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 359ms/step - accuracy: 0.6188 - loss: 1.3168
# 🔥 ResNet Accuracy: 0.6188271641731262
#
# 🚀 Training VGG19...
#
# Epoch 1/6
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.2963 - loss: 4.3443 - val_accuracy: 0.2647 - val_loss: 2.5837 - learning_rate: 1.0000e-05
# Epoch 2/6
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 767ms/step - accuracy: 0.3218 - loss: 3.4243
# Epoch 2: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 105s 998ms/step - accuracy: 0.3384 - loss: 3.3045 - val_accuracy: 0.3174 - val_loss: 1.9831 - learning_rate: 1.0000e-05
# Epoch 3/6
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.3740 - loss: 2.9877 - val_accuracy: 0.3964 - val_loss: 1.8208 - learning_rate: 5.0000e-06
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step
#               precision    recall  f1-score   support
#
#       normal       0.36      0.46      0.40       227
#   osteopenia       0.28      0.26      0.27       186
# osteoporosis       0.52      0.42      0.46       235
#
#     accuracy                           0.39       648
#    macro avg       0.39      0.38      0.38       648
# weighted avg       0.40      0.39      0.39       648
#
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 303ms/step - accuracy: 0.3858 - loss: 2.2910
# 🔥 VGG19 Accuracy: 0.3858024775981903
#
# 🚀 Training DenseNet...
#
# Epoch 1/6
#  45/105 ━━━━━━━━━━━━━━━━━━━━ 52s 872ms/step - accuracy: 0.3343 - loss: 7.6316
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1922/3808458223.py in <cell line: 0>()
#     212 results["ResNet"]   = train_model(build_resnet(), "ResNet", epochs_resnet)
#     213 results["VGG19"]    = train_model(build_vgg(), "VGG19", epochs_other)
# --> 214 results["DenseNet"] = train_model(build_densenet(), "DenseNet", epochs_other)
#     215 results["AlexNet"]  = train_model(build_alexnet(), "AlexNet", epochs_other)
#     216
#
# /tmp/ipykernel_1922/3808458223.py in train_model(model, name, epochs)
#     160     )
#     161
# --> 162     history = model.fit(
#     163         train_generator,
#     164         validation_data=val_generator,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397                 for begin_step, end_step, iterator in epoch_iterator:
#     398                     callbacks.on_train_batch_begin(begin_step)
# --> 399                     logs = self.train_function(iterator)
#     400                     callbacks.on_train_batch_end(end_step, logs)
#     401                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     239                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240             ):
# --> 241                 opt_outputs = multi_step_on_iterator(iterator)
#     242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
