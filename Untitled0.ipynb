# %% [markdown]
# <a href="https://colab.research.google.com/github/Anagha264/Anagha/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print(os.listdir('/content/drive'))
# Out:
# ['.shortcut-targets-by-id', 'MyDrive', '.Trash-0']

# %%
print(os.listdir('/content/drive/MyDrive'))
# Out:
# ['Colab Notebooks', 'CTE Sjec', '4th Notes ', 'Document ', '1st year', 'Et', '5th sem', 'project ', 'DOC-20250913-WA0014 (1).gdoc', 'DOC-20250913-WA0014.gdoc', 'dspassignment15lasst.pptx', 'VID_20250915_195600344.mp4', 'Anagha_.jpg', 'DOC-20250927-WA0040.gdoc', 'Pbl', 'Ppt', '4SO23EC010.pdf', 'Untitled document (16).gdoc', 'Untitled document (15).gdoc', 'Untitled document (14).gdoc', 'Untitled presentation (1).gslides', 'Untitled document (13).gdoc', 'Submission ', 'Placement ', 'Chatbot Flask Backend', 'Air Pollution Detector Backend', 'Untitled document (12).gdoc', 'Lab ', 'Untitled presentation.gslides', 'linked.docx', 'ARM  MANUAL (REV-25-26) (1).gdoc', 'ARM  MANUAL (REV-25-26).gdoc', 'Untitled document (11).gdoc', 'G11.pptx', 'Untitled document (10).gdoc', 'Untitled document (9).gdoc', 'Untitled document (8).gdoc', 'Untitled document (7).gdoc', 'Untitled document (6).gdoc', 'Final Course List (Jan - Apr 2026).xlsx', 'CMOS_VLSI_Assignment.docx', 'Untitled document (5).gdoc', 'IIP
# ...

# %%
print(os.listdir('/content/drive/MyDrive/Ostroporosis'))
# Out:
# ['dataset']

# %%
print(os.listdir('/content/drive/MyDrive/Ostroporosis/dataset'))
# Out:
# ['test', 'train']

# %%
train_dir = "/content/drive/MyDrive/Ostroporosis/dataset/train"
test_dir = "/content/drive/MyDrive/Ostroporosis/dataset/test"

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# ================== MOUNT GOOGLE DRIVE ==================
from google.colab import drive
drive.mount('/content/drive')

# ================== IMPORTS ==================
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50, VGG19, DenseNet121
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# ================== PATHS (FIXED) ==================
train_dir = "/content/drive/MyDrive/Ostroporosis/dataset/train"
test_dir  = "/content/drive/MyDrive/Ostroporosis/dataset/test"

# ================== PARAMETERS ==================
img_height, img_width = 224, 224
batch_size = 8
epochs = 5

# ================== DATA GENERATORS ==================
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen  = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# ================== MODELS ==================

def build_resnet():
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))

    for layer in base_model.layers[:-30]:
        layer.trainable = False
    for layer in base_model.layers[-30:]:
        layer.trainable = True

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(3, activation='softmax')(x)

    return Model(inputs=base_model.input, outputs=output)


def build_vgg():
    base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224,224,3))
    base_model.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    output = Dense(3, activation='softmax')(x)

    return Model(inputs=base_model.input, outputs=output)


def build_densenet():
    base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224,224,3))
    base_model.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    output = Dense(3, activation='softmax')(x)

    return Model(inputs=base_model.input, outputs=output)


def build_alexnet():
    model = Sequential([
        Conv2D(96, (11,11), strides=4, activation='relu', input_shape=(224,224,3)),
        MaxPooling2D((3,3), strides=2),
        Conv2D(256, (5,5), padding='same', activation='relu'),
        MaxPooling2D((3,3), strides=2),
        Conv2D(384, (3,3), padding='same', activation='relu'),
        Conv2D(384, (3,3), padding='same', activation='relu'),
        Conv2D(256, (3,3), padding='same', activation='relu'),
        MaxPooling2D((3,3), strides=2),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(3, activation='softmax')
    ])
    return model

# ================== TRAIN FUNCTION ==================

def train_model(model, name):
    print(f"\nTraining {name}...\n")

    model.compile(optimizer=Adam(1e-5),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(
        train_generator,
        validation_data=test_generator,
        epochs=epochs
    )

    # 📈 Accuracy & Loss Graph
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(12,5))

    plt.subplot(1,2,1)
    plt.plot(acc)
    plt.plot(val_acc)
    plt.title(f"{name} Accuracy")

    plt.subplot(1,2,2)
    plt.plot(loss)
    plt.plot(val_loss)
    plt.title(f"{name} Loss")

    plt.show()

    # 📊 Confusion Matrix
    y_pred = model.predict(test_generator)
    y_pred_classes = np.argmax(y_pred, axis=1)

    cm = confusion_matrix(test_generator.classes, y_pred_classes)

    plt.figure()
    sns.heatmap(cm, annot=True, fmt='d')
    plt.title(f"{name} Confusion Matrix")
    plt.show()

    # 📄 Classification Report
    print(classification_report(
        test_generator.classes,
        y_pred_classes,
        target_names=list(test_generator.class_indices.keys())
    ))

    # ✅ Final Accuracy
    score = model.evaluate(test_generator)
    print(f"{name} Accuracy: {score[1]}")

    return score[1]

# ================== RUN ==================

results = {}

results["ResNet"] = train_model(build_resnet(), "ResNet")
results["VGG19"] = train_model(build_vgg(), "VGG19")
results["DenseNet"] = train_model(build_densenet(), "DenseNet")
results["AlexNet"] = train_model(build_alexnet(), "AlexNet")

print("\nFinal Comparison:")
for model, acc in results.items():
    print(f"{model}: {acc}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 33 images belonging to 3 classes.
# Found 646 images belonging to 3 classes.
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# Training ResNet...
#
# Epoch 1/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 223s 49s/step - accuracy: 0.5455 - loss: 1.0478 - val_accuracy: 0.2848 - val_loss: 1.1815
# Epoch 2/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 1.0000 - loss: 0.3172 - val_accuracy: 0.2848 - val_loss: 1.1815
# Epoch 3/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 1.0000 - loss: 0.1648 - val_accuracy: 0.2848 - val_loss: 1.1826
# Epoch 4/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 1.0000 - loss: 0.0642 - val_accuracy: 0.2848 - val_loss: 1.1825
# Epoch 5/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 1.0000 - loss: 0.0557 - val_accuracy: 0.2848 - val_loss: 1.1812
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 144ms/step
# ...
